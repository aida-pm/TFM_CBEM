# %%
def STLtoNIfTI(Reference_volume,input_STL,output_STL):
    referenceVolumeNode = slicer.util.loadVolume(Reference_volume,{'singleFile': False})
    segmentationNode=slicer.util.loadSegmentation(input_STL)
    labelmapVolumeNode = slicer.mrmlScene.AddNewNodeByClass('vtkMRMLLabelMapVolumeNode')
    slicer.modules.segmentations.logic().ExportVisibleSegmentsToLabelmapNode(segmentationNode, labelmapVolumeNode, referenceVolumeNode)
    #the last line of code was to create the segmentation according to the volume
    mynode=labelmapVolumeNode
    myStorageNode=mynode.CreateDefaultStorageNode()
    myStorageNode.SetFileName(output_STL)
    myStorageNode.WriteData(mynode)
    print('NIfTI file of the segmentation successfully created')
    slicer.mrmlScene.RemoveNode(labelmapVolumeNode)
    slicer.mrmlScene.RemoveNode(myStorageNode)

# %%
import glob 
import re

vpath = 'E:\\Imatges\\'
#spath1 = 'E:\\Observer_1\\'
spath1 = 'E:\\Observer_2\\'

#output_path = 'E:\\Observer1_new\\'
output_path = 'E:\\Observer2_new\\'

ims = glob.glob(vpath+"\\*.nii.gz")
#mask1 = glob.glob(spath1+"\\*.stl")
mask1 = glob.glob(spath1+"\\*.stl")

for i in range(0,len(ims)):
    case =  re.sub("[^0-9]", "", mask1[i][-9:-6])
    Reference_volume=vpath + 'Case' + str(case) + '.nii.gz'
    input_STL = mask1[i]
    output_STL=output_path + 'case'+ str(case) + '_1.nii.gz'
    STLtoNIfTI(Reference_volume,input_STL,output_STL)
# Out:
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# ...

# %%
import glob 
import re

vpath = 'E:\\new4d_LV\\Magnitude\\' #E:\\Fourflow\\Magnitude\\
spath1 = 'E:\\new4d_LV\\Segmentations\\' #E:\\Fourflow\\Segmentations\\

output_path = 'E:\\LV_seg\\'

ims = glob.glob(vpath+"\\*.nii.gz")

mask1 = glob.glob(spath1+"\\*.nrrd")

for i in range(0,len(ims)):
    case =  re.sub("[^0-9]", "", mask1[i][-17:-7])
    Reference_volume=vpath + 'Case' + str(case) + '.nii.gz'
    input_STL = mask1[i]
    output_STL=output_path + 'case'+ str(case) + '_1.nii.gz'
    STLtoNIfTI(Reference_volume,input_STL,output_STL)
# Out:
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# ...

# %% [markdown]
# # BACKWARDS

# %%
import glob 
import re

#vpath = 'E:\\4Dnet - LALAA\\nnUNet_raw_data_base\\nnUNet_raw_data\\Task005_LALAA\\imagesTs\\' 
vpath = 'E:\\Prova_rescale\\testing\\'
#spath1 = 'E:\\4Dnet - LALAA\\nnUNet_raw_data_base\\nnUNet_raw_data\\Task005_LALAA\\labelsTs\\'
#spath1 = 'E:\\4Dnet - LALAA\\Predictions\\'
#spath1 = 'E:\\predict26\\'
spath1 = 'E:\\TL_GT\\'

#output_path = 'E:\\Visualization - 4Dflow\\' 
output_path = 'E:\\Visualization - TL\\' 

ims = glob.glob(vpath+"\\*.nii.gz")

mask1 = glob.glob(spath1+"\\*.nii.gz")

for i in range(0,len(mask1)):
    case =  re.sub("[^0-9]", "", mask1[i][-20:-9])
    Reference_volume=vpath + 'Case' +str(case) + '.nii.gz'
    #Reference_volume=vpath + str(case) + '_0000.nii.gz'
    input_STL = mask1[i]
    output_STL=output_path + 'gt_'+ str(case) + '.nrrd'
    STLtoNIfTI(Reference_volume,input_STL,output_STL)
# Out:
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
# NIfTI file of the segmentation successfully created
